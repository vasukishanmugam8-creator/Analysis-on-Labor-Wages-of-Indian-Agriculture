# %% [markdown]
# # **ANALYSIS ON LABOUR WAGES OF INDIAN AGRICULTURE (2010-2020)**

# %% [markdown]
# # **Problem statment**
#
# Agricultural wages vary significantly across different states, districts, labor categories, and genders in India. Understanding these variations is essential for identifying wage disparities, evaluating labor market conditions, and supporting policy decisions. However, the large volume of wage data makes it difficult to extract meaningful insights without systematic analysis. This project aims to analyze agricultural wage data using Exploratory Data Analysis (EDA) techniques to uncover patterns, trends, and factors influencing wage distribution across regions and time periods.

# %% [markdown]
# #**Objective**
#
# 1.   To clean, preprocess, and organize the agricultural wage dataset for   accurate analysis.
# 2.   To perform Exploratory Data Analysis (EDA) and identify trends, patterns, and anomalies in agricultural wages.
# 3.   To compare wages across states, districts, labor categories, and gender groups.
# 4.   To analyze wage trends over time and understand regional variations in agricultural labor earnings.
# 5.   To create effective visualizations that communicate key findings and support data-driven decision-making.
# 6.   To generate actionable insights and recommendations for improving wage equity and labor welfare in the agricultural sector.

# %% [markdown]
# # **Outcome**
#
#
# 1.  A clean and structured agricultural wage dataset ready for analysis.
# 2.  Identification of high-paying and low-paying states, districts, and labor categories.
# 3.  Insights into gender-based wage differences and regional wage disparities.
# 4.  Visualization dashboards and charts illustrating wage distributions and trends over time.
# 5.  Data-driven recommendations to support policymakers, researchers, and agricultural stakeholders.
# 6.  A comprehensive understanding of agricultural wage patterns that can help improve labor welfare strategies and economic planning.

# %% [markdown]
# # **Domain**
#
# Agriculture

# %% [markdown]
# #**Dataset Information**
#
# **Source:** India data portal <font color="blue"><u> **https://indiadataportal.com/p/agricultural-wages/r/moafw-agricultural_wages-ol-mn-aji**</font></u>
#
#
# **Year / Timeline:** 07/2010-06/2020
#
#
#
#  **Dataset Overview**
#
#
#  | Attribute         | Description                               |
# | ----------------- | ----------------------------------------- |
# | Total Records     | 776,112                                   |
# | Total Columns     | 14                                        |
# | States Covered    | 21                                        |
# | Districts Covered | 530                                       |
# | Time Period       | 2010–2019                                 |
# | Key Metrics       | Monthly Average Wage, Annual Average Wage |
#
#
#
#
#
#
#
#
#
# **Dataset Column/features Description:**
#
#
#
# * | Column Name              | Description                                                                                          |
# | ------------------------ | ---------------------------------------------------------------------------------------------------- |
# | **month**                | Month and year for which the wage data was recorded.                                                 |
# | **state_name**           | Name of the state where the agricultural wage data was collected.                                    |
# | **state_code**           | Unique code assigned to each state.                                                                  |
# | **district_name**        | Name of the district within the state.                                                               |
# | **district_code**        | Unique code assigned to each district.                                                               |
# | **center_name**          | Name of the data collection center or market center where wage information was gathered.             |
# | **center_code**          | Unique identification code for the data collection center.                                           |
# | **center_lat**           | Latitude coordinate of the data collection center.                                                   |
# | **center_long**          | Longitude coordinate of the data collection center.                                                  |
# | **labour_category**      | Category of agricultural labor (e.g., Field Labour, Herdsmen, Other Agricultural Labour).            |
# | **labour_type**          | Specific type of labor work performed by the worker.                                                 |
# | **gender**               | Gender of the worker (Men/Women).                                                                    |
# | **monthly_average_wage** | Average daily wage rate recorded for the specified month.                                            |
# | **annual_average_wage**  | Average wage rate calculated over the entire year for the corresponding labor category and location. |

# %% [markdown]
# # Stages for DA Project

# %% [markdown]
# ## Stage 1 – Problem Definition and Dataset Selection
#
#
# **NOTE : THINGS TO BE COMPLETED**
#
# * Define the business problem and expected outcome
#
# * Choose dataset and explain its source, size, and features
#
# * Import libraries, load dataset
#
# * Dataset description (rows, columns, features)
#
# * Initial EDA (head, info, describe, shape, null checks, duplicate check)

# %% [markdown]
# # **Inital EDA**

# %%
# !pip install pyxlsb

import pandas as pd

url = "https://github.com/vasukishanmugam8-creator/Analysis-on-Labor-Wages-of-Indian-Agriculture/raw/main/Analysis%20on%20Labour%20Wages%20of%20Indian%20Agriculture.xlsb"

df = pd.read_excel(url, engine="pyxlsb")


df.head()
# Out:
# Requirement already satisfied: pyxlsb in /usr/local/lib/python3.12/dist-packages (1.0.10)
#    month state_name  state_code district_name  district_code center_name  \
# 0  40185  Telangana          36      Adilabad            501       Basar
# 1  40185  Telangana          36      Adilabad            501       Basar
# 2  40185  Telangana          36      Adilabad            501       Basar
# 3  40185  Telangana          36      Adilabad            501       Basar
# 4  40185  Telangana          36      Adilabad            501       Basar
#
#    center_code  center_lat  center_long            labour_category  \
# 0       900988         0.0          0.0               Field Labour
# 1       900988         0.0          0.0               Field Labour
# 2       900988         0.0          0.0                   Herdsmen
# 3       900988         0.0          0.0                   Herdsmen
# 4       900988         0.0          0.0  Other Agricultural Labour
#
#                  labour_type gender  monthly_average_wage  annual_average_wage
# 0               Field Labour    Men                  95.0               162.92
# 1               Field Labour  Women                  80.0               140.00
# 2                   Herdsmen    Men                 150.0               150.83
# 3                   Herdsmen  Women                   0.0                 0.00
# 4  Other Agricultural Labour    Men                  75.0               137.92

# %%
# your code here
# If you want more cells, you can add or less cells you can remove, but dont change the structure.

# %%
# your code here
# If you want more cells, you can add or less cells you can remove, but dont change the structure.

# %%
# your code here
# If you want more cells, you can add or less cells you can remove, but dont change the structure.

# %%
# your code here
# If you want more cells, you can add or less cells you can remove, but dont change the structure.

# %%
# your code here
# If you want more cells, you can add or less cells you can remove, but dont change the structure.

# %% [markdown]
# ## Stage 2 – Data Cleaning and Pre-processing
#
# - Handle missing values (impute or drop)
#
# - Handle duplicates
# - column name rename or dropping unwanted columns if required
#
# - Treat outliers if required
#
# - Check skewness and apply transformations
#
# - Convert data types if needed
#
# - Feature transformations (date parts, derived fields if required for analysis)

# %%
# your code here
# If you want more cells, you can add or less cells you can remove, but dont change the structure.

# %%
# your code here
# If you want more cells, you can add or less cells you can remove, but dont change the structure.

# %%
# your code here
# If you want more cells, you can add or less cells you can remove, but dont change the structure.

# %%
# your code here
# If you want more cells, you can add or less cells you can remove, but dont change the structure.

# %%
# your code here
# If you want more cells, you can add or less cells you can remove, but dont change the structure.

# %% [markdown]
# ## Stage 3 – EDA and Visualizations
#
# Univariate Analysis → distribution of single variables (countplot, histogram, boxplot)
#
# Bivariate Analysis → relation between two variables (scatterplot, barplot, correlation heatmap)
#
# Multivariate Analysis → relation among 3+ variables (pairplot, grouped analysis, pivot tables, advanced plots)
#
# Interpretation MUST with every visualization
#
# Focus on business story not just charts
#
# Each chart must be in seperate cells.

# %% [markdown]
# # **Note For Kind of Analysis to be done**
#
# **Type of Analysis**
#
# * Descriptive Analysis (summarizing the dataset)
#
# * Diagnostic Analysis (finding reasons behind patterns)
#
# * Predictive Analysis (optional if forecasting required using basic stats)
#
# * Prescriptive Analysis (recommendations for business decisions)

# %% [markdown]
# ### Analysis about the sales by region

# %%
# your chart here
# If you want more cells, you can add or less cells you can remove, but dont change the structure.

# %% [markdown]
# ### **Insights**
#
# * point by point insight should be recorded

# %% [markdown]
# ## Interpretation of your above chart
#
# Explain the Chart.
#
# What is it saying?
#
# What features you used?
#
# From this what you are showing us?

# %%
# your code here
# If you want more cells, you can add or less cells you can remove, but dont change the structure.

# %%
a=10
print("hai")
# Out:
#   File "/tmp/ipykernel_607/2666902648.py", line 2
#     print("hai")
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ## Interpretation of your above chart
#
# Explain the Chart.
#
# What is it saying?
#
# What features you used?
#
# From this what you are showing us?

# %%
# your code here
# If you want more cells, you can add or less cells you can remove, but dont change the structure.

# %% [markdown]
# ## Interpretation of your above chart
#
# Explain the Chart.
#
# What is it saying?
#
# What features you used?
#
# From this what you are showing us?

# %%
# your code here
# If you want more cells, you can add or less cells you can remove, but dont change the structure.

# %% [markdown]
# ## Interpretation of your above chart
#
# Explain the Chart.
#
# What is it saying?
#
# What features you used?
#
# From this what you are showing us?

# %%
# your code here
# If you want more cells, you can add or less cells you can remove, but dont change the structure.

# %% [markdown]
# ## Interpretation of your above chart
#
# Explain the Chart.
#
# What is it saying?
#
# What features/columns you used?
#
# From this what you are showing us?

# %% [markdown]
# ## **Steps to Download your cleaned data for dashboard creation using Power BI**

# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/geethag-sys/Health-care-analysis3/refs/heads/main/insurance.csv")
df.to_csv("insurance.csv")

# %% [markdown]
# ## Stage 4 – Documentation, Insights and Presentation
#
# Show a dashboard aligning all the charts in powerbi by connecting python in PowerBI
#
# Summarize findings in plain English (what do the patterns mean)
#
# Highlight 3–5 key insights (trends, anomalies, correlations)
#
# Provide recommendations for business or decision-making
#
# Explain the FINAL STORY WITH THE DASHBOARD/report
#
# Create a PDF pasting your DASHBOARD, explaining all the above mentioned concepts and submit it

# %% [markdown]
# ![dash-img.png](data:image/png;base64,...)

# %%
# your stage 4 pdf Link

'''
step1 --> Create a docs that should have all the above mentioned
step2 --> Save it as "Stage4_doc"
Step3 --> Download it as PDF
step4 --> Upload the pdf in your drive
step5 --> Right click on your pdf in drive
step6 --> click share and change access into anyone with the link (Viewer)
step7 --> click copy link and paste it here...
You are done.
'''

# %% [markdown]
# ## **Final Overall Insights:**
# * insights from the final dashboard observation on the basics of 4 types of analysis

# %% [markdown]
# # Future Enhancement
#
# Use a larger or more recent dataset for deeper insights
#
# Automate parts of the analysis with scripts or dashboards
#
# Add advanced visualizations and interactive dashboards in Power BI or Tableau
#
# Extend the analysis to predictive modeling for forecasting if needed

# %% [markdown]
# # Conclusion
#
# From the analysis, we identified meaningful relationships and patterns in the dataset. The visualizations and insights highlight the main factors influencing the outcomes and provide a strong foundation for business decisions.
